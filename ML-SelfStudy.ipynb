# %% [markdown]
# ## Self Study for INFO 4604

# %%
import pandas as pd
import numpy as np
import altair as alt

import matplotlib.pyplot as plt

pd.options.display.max_columns = 100

print("Check versions !")
print(alt.__version__)
print(np.__version__)
print(pd.__version__)
# Out:
# Check versions !
# 4.1.0
# 1.21.0
# 1.3.2

# %%
##getting to know the data

athletes_df = pd.read_csv('/Users/sashamaslowski/Desktop/athletes.csv')

leaderboard_df = pd.read_csv('/Users/sashamaslowski/Desktop/leaderboard.15.csv')




athletes_df = athletes_df[athletes_df['fran'].notna()]
athletes_df = athletes_df[athletes_df['helen'].notna()]
athletes_df = athletes_df[athletes_df['grace'].notna()]
athletes_df = athletes_df[athletes_df['filthy50'].notna()]
athletes_df = athletes_df[athletes_df['fgonebad'].notna()]
athletes_df = athletes_df[athletes_df['run400'].notna()]
athletes_df = athletes_df[athletes_df['run5k'].notna()]
athletes_df = athletes_df[athletes_df['candj'].notna()]
athletes_df = athletes_df[athletes_df['snatch'].notna()]
athletes_df = athletes_df[athletes_df['deadlift'].notna()]
athletes_df = athletes_df[athletes_df['backsq'].notna()]
athletes_df = athletes_df[athletes_df['pullups'].notna()]


# plt.scatter(x=athletes_df["weight"], y=athletes_df["run400"])
# #plt.colorbar()
# plt.show()



athletes_df.head()
# Out:
#      athlete_id              name         region                team  \
# 12      11416.0     Mike Abgarian            NaN                 NaN
# 102      2720.0      Justin Adams  South Central   Woodward CrossFit
# 110      6922.0    Daniel Adamson     South West  CrossFit The Point
# 116     12563.0  Steven Lee Adams   Mid Atlantic      CrossFit Kaiju
# 124     17515.0       jaime acuna            NaN                 NaN
#
#               affiliate gender   age  height  weight   fran  helen  grace  \
# 12                  NaN   Male  31.0    65.0   150.0  119.0  417.0  103.0
# 102   Woodward CrossFit   Male  24.0    68.0   180.0  126.0  449.0   86.0
# 110  CrossFit The Point   Male  31.0    67.0   150.0  244.0  486.0  294.0
# 116      CrossFit Kaiju   Male  37.0    72.0   210.0  162.0  482.0  143.0
# 124                 NaN   Male  23.0    71.0   175.0  134.0  478.0  100.0
#
#      filthy50  fgonebad  run400   run5k  candj  snatch  deadlift  backsq  \
# ...
